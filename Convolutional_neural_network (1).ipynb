# %% [markdown]
# # Lab Part 4
# # Neural Network Model Template
#
# This file contains boilerplate for creating a neural network. Designing a neural network is quite difficult and requires a lot of time to set up data processing pipelines and image processing. As well as making sure that the tensors and datasets are in the correct formats. This file contains all that you need to make your very own neural network.

# %%
# Config Parameters for the model
# Set the batch size here
# increase for systems with more memory, 32 should be enough for most systems
BATCH_SIZE = 32

# %% [markdown]
# ## Part 1: Unpack our data
# All we do is install 7zip and then use pyunpack to extract the files. This saves datasets to /notebooks which is a directory on Paperspace Gradient that is acceptable by python.

# %%
# Mount Google Drive
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)

import zipfile

# dataset file name
data_file = "data_9" # change this to your dataset file name

zip_ref = zipfile.ZipFile("/content/gdrive/MyDrive/data_9.zip", 'r')
zip_ref.extractall()
zip_ref.close()

data_dir = '/content/' + data_file + '/'
train_dir = data_dir + 'train/' # directory for training images
test_dir = data_dir + 'test/' # directory for test images we use the test images to make sure our model is working well
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Part 3: Loading in the data
# ### Dealing with images
# Our image files that we are using for training are pretty large. Your computer may crash if we loaded them all at once so instead we will just store where the images are stored. Later you will see how we can automatically load these files when we run our code. One thing to note is that each image file is named (somenumber).jpg that number is the number of milliseconds since 1 January 1970 (Unix Time) when the file was recorded. This means that we will never have any overlapping files. Unfortunately this does mean we will have to sort the times from smallest to largest to make sure that they correspond with the steering angles which are recorded sequentially.
#
# ### Dealing with steering angles
# We store our steering values as a csv (comma separated values) file. Python has a built in csv module so we can easily use it to load in all the steering values into a list. These don't take up much ram so it doesn't matter if we load them all in at once. They're just numbers after all.
#
# ### Making sure the files line up
# Since we sort our images, and the csv file is read in line by line the files will line up with their correct steering angles. It looks something like this. If we mess this up then the data being fed into your network would be totally incoherent. Garbage in Garbage out.
#
# train_img =   | image 1    | image 2    | image 3    | image 4    | image 5    |...
#
# train_steer = | steering 1 | steering 2 | steering 3 | steering 4 | steering 5 |...

# %%
import csv
import os
# lets make a function that loads the images and labels
def load_data(directory):
    image__paths = []
    for file in os.listdir(directory): # for each file in the directory
        if file.endswith(".png"): # if the file is an image
            image__paths.append(directory + file) # add the image path to the list
    print(image__paths)
    # now our files are in the train list we need to sort them from smallest file name to largest. The file name is the exact time the image was taken.
    image__paths.sort(key=lambda x: int(x.split('/')[-1][:-4].split('_')[0][:])) # the lambda function returns the numbers in the file name
    print(image__paths)
    # now we get the steering angles
    steering_angles = [] # create a list to store the steering angles
    for angle in image__paths: # for each row in the csv file
        steering_angles.append(float(angle.split('/')[-1][:-4].split('_')[-1].replace('-','.'))) # add the steering angle to the list
    print(steering_angles)
    return image__paths, steering_angles # return the image paths and steering angles

# We call our load data function to get the image paths and steering angles
train_img, train_steer = load_data(train_dir) # load the training data
test_img, test_steer = load_data(test_dir) # load the test data
# Out:
# ['/content/data_9/train/4207_15.png', '/content/data_9/train/3345_79-729.png', '/content/data_9/train/3858_82-551.png', '/content/data_9/train/7392_78-207.png', '/content/data_9/train/3000_77-663.png', '/content/data_9/train/2150_82-235.png', '/content/data_9/train/2391_75-519.png', '/content/data_9/train/7786_58-165.png', '/content/data_9/train/2744_100-283.png', '/content/data_9/train/9456_138-28.png', '/content/data_9/train/5499_65-192.png', '/content/data_9/train/3054_86-818.png', '/content/data_9/train/2813_94-909.png', '/content/data_9/train/5637_86-197.png', '/content/data_9/train/348_95-725.png', '/content/data_9/train/4230_22-631.png', '/content/data_9/train/3696_97-199.png', '/content/data_9/train/7484_60-305.png', '/content/data_9/train/1768_91-502.png', '/content/data_9/train/5722_96-517.png', '/content/data_9/train/719_72-846.png', '/content/data_9/train/8887_64-916.png', '/content/data_9/train/1949_90-302.png', '/content/data_9/train/5829_107-051.png', '/content/data_9/train/3782_93-535.png', '/content/data_9/train/4067_94-803.png', '/content/data_9/train/6816_106-834.png', '/content/data_9/train/4548_90-197.png', '/content/data_9/train/3732_95-859.png', '/content/data_9/train/6661_53-2.png', '/content/data_9/train/9234_72-884.png', '/content/data_9/train/3914_23-976.png', '/content/data_9/train/6926_15.png', '/content/data_9/train/5885_100-396.png', '/content/data_9/train/4418_115-58.png', '/content/data_9/train/7870_73-045.png', '/content/data_9/train/235_84-551.png', '/content/data_9/train/131_103-318.png', '/content/data_9/train/1003_108-725.png', '/content/data_9/train/2896_88-985.png', '/content/data_9/train/3638_104-99.png', '/content/data_9/train/9994_82-768.png', '/content/data_9/train/9249_74-96.png', '/content/data_9/train/7543_82-383.png', '/content/data_9/train/2966_67-745.png', '/content/data_9/train/6787_118-706.png', '/content/data_9/train/9122_85-45.png', '/content/data_9/train/7545_82-687.png', '/content/data_9/train/4474_126-786.png', '/content/data_9/train/5263_85-908.png', '/content/data_9/train/7746_95-206.png', '/content/data_9/train/1996_87-367.png', '/content/data_9/train/3427_86-134.png', '/content/data_9/train/242_84-746.png', '/content/data_9/train/9014_81-257.png', '/content/data_9/train/1888_93-47.png', '/content/data_9/train/7471_42-225.png', '/content/data_9/train/2580_154-609.png', '/content/data_9/train/7540_81-908.png', '/content/data_9/train/2793_96-337.png', '/content/data_9/train/7630_95-726.png', '/content/data_9/train/8631_107-558.png', '/content/data_9/train/6030_82-621.png', '/content/data_9/train/9582_107-077.png', '/content/data_9/train/9755_91-48.png', '/content/data_9/train/7773_89-744.png', '/content/data_9/train/2746_100-13.png', '/content/data_9/train/3592_119-777.png', '/content/data_9/train/5590_82-089.png', '/content/data_9/train/4467_131-415.png', '/content/data_9/train/4002_83-888.png', '/content/data_9/train/560_84-312.png', '/content/data_9/train/4604_86-826.png', '/content/data_9/train/7602_89-721.png', '/content/data_9/train/8211_74-679.png', '/content/data_9/train/2302_72-751.png', '/content/data_9/train/6309_86-379.png', '/content/data_9/train/5488_61-705.png', '/content/data_9/train/7274_114-537.png', '/content/data_9/train/9032_84-072.png', '/content/data_9/train/4013_86-017.png', '/content/data_9/train/677_108-12.png', '/content/data_9/train/5311_92-583.png', '/content/data_9/train/7089_123-785.png', '/content/data_9/train/6488_92-407.png', '/content/data_9/train/3187_75-302.png', '/content/data_9/train/9888_67-815.png', '/content/data_9/train/5108_84-06.png', '/content/data_9/train/7306_114-992.png', '/content/data_9/train/3857_83-464.png', '/content/data_9/train/7321_113-562.png', '/content/data_9/train/261_86-687.png', '/content/data_9/train/5285_89-066.png', '/content/data_9/train/3169_83-832.png', '/content/data_9/train/9441_156-814.png', '/content/data_9/train/6805_112-817.png', '/content/data_9/train/836_78-75.png', '/content/data_9/train/7114_ ...
# ['/content/data_9/train/0_104-107.png', '/content/data_9/train/1_104-465.png', '/content/data_9/train/2_104-806.png', '/content/data_9/train/3_105-144.png', '/content/data_9/train/4_105-448.png', '/content/data_9/train/5_105-764.png', '/content/data_9/train/6_106-058.png', '/content/data_9/train/7_106-315.png', '/content/data_9/train/8_106-567.png', '/content/data_9/train/9_106-812.png', '/content/data_9/train/10_107-026.png', '/content/data_9/train/11_107-253.png', '/content/data_9/train/12_107-462.png', '/content/data_9/train/13_107-641.png', '/content/data_9/train/14_107-802.png', '/content/data_9/train/15_107-979.png', '/content/data_9/train/16_108-126.png', '/content/data_9/train/17_108-286.png', '/content/data_9/train/18_108-435.png', '/content/data_9/train/19_108-558.png', '/content/data_9/train/20_108-655.png', '/content/data_9/train/21_108-777.png', '/content/data_9/train/22_108-879.png', '/content/data_9/train/23_108-997.png', '/content/data_9/train/24_109-108.png', '/content/data_9/train/25_109-195.png', '/content/data_9/train/26_109-255.png', '/content/data_9/train/27_109-323.png', '/content/data_9/train/28_109-396.png', '/content/data_9/train/29_109-502.png', '/content/data_9/train/30_109-597.png', '/content/data_9/train/31_109-666.png', '/content/data_9/train/32_109-71.png', '/content/data_9/train/33_109-735.png', '/content/data_9/train/34_109-799.png', '/content/data_9/train/35_109-946.png', '/content/data_9/train/36_110-056.png', '/content/data_9/train/37_110-135.png', '/content/data_9/train/38_110-187.png', '/content/data_9/train/39_110-209.png', '/content/data_9/train/40_110-284.png', '/content/data_9/train/41_110-422.png', '/content/data_9/train/42_110-52.png', '/content/data_9/train/43_110-583.png', '/content/data_9/train/44_110-618.png', '/content/data_9/train/45_110-622.png', '/content/data_9/train/46_110-65.png', '/content/data_9/train/47_110-754.png', '/content/data_9/train/48_110-82.png', '/content/data_9/train/49_110-849.png', '/content/data_9/train/50_110-849.png', '/content/data_9/train/51_110-821.png', '/content/data_9/train/52_110-778.png', '/content/data_9/train/53_110-833.png', '/content/data_9/train/54_110-858.png', '/content/data_9/train/55_110-85.png', '/content/data_9/train/56_110-811.png', '/content/data_9/train/57_110-749.png', '/content/data_9/train/58_110-661.png', '/content/data_9/train/59_110-635.png', '/content/data_9/train/60_110-625.png', '/content/data_9/train/61_110-585.png', '/content/data_9/train/62_110-515.png', '/content/data_9/train/63_110-423.png', '/content/data_9/train/64_110-31.png', '/content/data_9/train/65_110-215.png', '/content/data_9/train/66_110-169.png', '/content/data_9/train/67_110-105.png', '/content/data_9/train/68_110-016.png', '/content/data_9/train/69_109-904.png', '/content/data_9/train/70_109-775.png', '/content/data_9/train/71_109-663.png', '/content/data_9/train/72_109-584.png', '/content/data_9/train/73_109-505.png', '/content/data_9/train/74_109-412.png', '/content/data_9/train/75_109-297.png', '/content/data_9/train/76_109-168.png', '/content/data_9/train/77_109-057.png', '/content/data_9/train/78_109-008.png', '/content/data_9/train/79_108-945.png', '/content/data_9/train/80_108-872.png', '/content/data_9/train/81_108-79.png', '/content/data_9/train/82_108-691.png', '/content/data_9/train/83_108-584.png', '/content/data_9/train/84_108-536.png', '/content/data_9/train/85_108-495.png', '/content/data_9/train/86_108-433.png', '/content/data_9/train/87_108-355.png', '/content/data_9/train/88_108-275.png', '/content/data_9/train/89_108-179.png', '/content/data_9/train/90_108-106.png', '/content/data_9/train/91_108-071.png', '/content/data_9/train/92_108-017.png', '/content/data_9/train/93_107-945.png', '/content/data_9/train/94_107-858.png', '/content/data_9/train/95_107-771.png', '/content/data_9/train/96_107-676.png', '/content/data_9/train/97_107-632.png', '/content/data_9/train/98_107-576.png', '/content/data_9/train/99_107-503.png', '/content/data_9 ...
# [104.107, 104.465, 104.806, 105.144, 105.448, 105.764, 106.058, 106.315, 106.567, 106.812, 107.026, 107.253, 107.462, 107.641, 107.802, 107.979, 108.126, 108.286, 108.435, 108.558, 108.655, 108.777, 108.879, 108.997, 109.108, 109.195, 109.255, 109.323, 109.396, 109.502, 109.597, 109.666, 109.71, 109.735, 109.799, 109.946, 110.056, 110.135, 110.187, 110.209, 110.284, 110.422, 110.52, 110.583, 110.618, 110.622, 110.65, 110.754, 110.82, 110.849, 110.849, 110.821, 110.778, 110.833, 110.858, 110.85, 110.811, 110.749, 110.661, 110.635, 110.625, 110.585, 110.515, 110.423, 110.31, 110.215, 110.169, 110.105, 110.016, 109.904, 109.775, 109.663, 109.584, 109.505, 109.412, 109.297, 109.168, 109.057, 109.008, 108.945, 108.872, 108.79, 108.691, 108.584, 108.536, 108.495, 108.433, 108.355, 108.275, 108.179, 108.106, 108.071, 108.017, 107.945, 107.858, 107.771, 107.676, 107.632, 107.576, 107.503, 107.416, 107.318, 107.207, 107.131, 107.06, 106.975, 106.876, 106.767, 106.648, 106.539, 106.452, 106.353, 106.237, 106.108, 105.972, 105.832, 105.722, 105.601, 105.471, 105.32, 105.162, 104.997, 104.857, 104.71, 104.559, 104.394, 104.209, 104.021, 103.849, 103.675, 103.499, 103.318, 103.103, 102.89, 102.686, 102.484, 102.283, 102.078, 101.832, 101.592, 101.355, 101.122, 100.892, 100.636, 100.357, 100.087, 99.822, 99.564, 99.297, 98.974, 98.666, 98.367, 98.077, 97.787, 97.457, 97.14, 96.834, 96.539, 96.245, 95.923, 95.612, 95.314, 95.026, 94.742, 94.438, 94.145, 93.865, 93.597, 93.334, 93.057, 92.794, 92.545, 92.309, 92.075, 91.844, 91.627, 91.424, 91.232, 91.052, 90.881, 90.725, 90.584, 90.459, 90.348, 90.251, 90.169, 90.103, 90.054, 90.02, 90.003, 89.998, 89.982, 89.949, 89.9, 89.834, 89.753, 89.656, 89.544, 89.419, 89.281, 89.131, 88.97, 88.8, 88.621, 88.435, 88.243, 88.045, 87.844, 87.643, 87.439, 87.236, 87.033, 86.832, 86.635, 86.445, 86.269, 86.099, 85.934, 85.775, 85.623, 85.488, 85.364, 85.247, 85.136, 85.033, 84.939, 84.865, 84.797, 84.736, 84.681, 84.632, 84.599, 84.58, 84.566, 84.557, 84.551, 84.55, 84.573, 84.602, 84.633, 84.666, 84.702, 84.746, 84.812, 84.878, 84.945, 85.013, 85.08, 85.168, 85.264, 85.359, 85.452, 85.543, 85.64, 85.764, 85.886, 86.004, 86.118, 86.23, 86.383, 86.538, 86.687, 86.831, 86.97, 87.119, 87.287, 87.448, 87.601, 87.749, 87.889, 88.044, 88.198, 88.344, 88.483, 88.614, 88.738, 88.871, 88.996, 89.114, 89.223, 89.324, 89.418, 89.513, 89.599, 89.676, 89.745, 89.806, 89.858, 89.905, 89.942, 89.97, 89.989, 89.999, 90.001, 90.011, 90.031, 90.061, 90.102, 90.152, 90.213, 90.284, 90.366, 90.457, 90.557, 90.666, 90.782, 90.906, 91.038, 91.177, 91.321, 91.471, 91.625, 91.785, 91.95, 92.117, 92.282, 92.448, 92.618, 92.788, 92.96, 93.131, 93.291, 93.451, 93.611, 93.77, 93.927, 94.082, 94.218, 94.353, 94.486, 94.618, 94.747, 94.868, 94.967, 95.065, 95.162, 95.256, 95.349, 95.422, 95.478, 95.532, 95.585, 95.637, 95.687, 95.698, 95.706, 95.712, 95.719, 95.725, 95.709, 95.662, 95.617, 95.572, 95.529, 95.48, 95.373, 95.27, 95.17, 95.073, 94.973, 94.806, 94.641, 94.481, 94.326, 94.157, 93.922, 93.696, 93.479, 93.269, 93.003, 92.716, 92.444, 92.185, 91.906, 91.584, 91.289, 91.023, 90.755, 90.463, 90.237, 90.085, 90.009, 89.988, 89.858, 89.563, 89.103, 88.355, 87.315, 86.007, 84.246, 82.185, 79.679, 76.858, 73.811, 70.553, 67.275, 63.907, 60.705, 57.477, 54.468, 51.487, 48.616, 45.982, 43.294, 40.749, 38.417, 36.015, 33.73, 31.637, 29.521, 27.433, 25.508, 23.718, 21.824, 20.099, 19.002, 18.155, 17.317, 16.669, 16.231, 15.992, 16.001, 16.067, 16.221, 16.565, 17.074, 17.725, 18.502, 19.266, 20.039, 20.898, 21.851, 22.885, 23.934, 24.938, 25.849, 26.77, 27.728, 28.69, 29.589, 30.262, 30.878, 31.512, 32.166, 32.505, 32.688, 32.867, 32.983, 32.855, 32.658, 32.383, 31.885, 31.401, 30.792, 30.068, 29.397, 28.607, 27.784, 26.984, 26.072, 25.198, 24.375, 23.473, 22.515, 21.54, 20.657, 19.785, 18.919, 18.054, 17.181, 16.487, 15.849, 15.248, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.271, 16.057, 16.928, 17.948, 19.158, 20.4 ...
# ['/content/data_9/test/11669_73-138.png', '/content/data_9/test/11344_86-17.png', '/content/data_9/test/12065_141-78.png', '/content/data_9/test/11006_69-464.png', '/content/data_9/test/10376_78-279.png', '/content/data_9/test/10092_77-977.png', '/content/data_9/test/12891_75-291.png', '/content/data_9/test/12077_133-14.png', '/content/data_9/test/11590_33-34.png', '/content/data_9/test/12758_87-477.png', '/content/data_9/test/12870_74-646.png', '/content/data_9/test/11569_77-01.png', '/content/data_9/test/12258_84-489.png', '/content/data_9/test/10837_111-15.png', '/content/data_9/test/10240_82-207.png', '/content/data_9/test/10987_70-645.png', '/content/data_9/test/11148_69-716.png', '/content/data_9/test/12278_89-838.png', '/content/data_9/test/10441_116-18.png', '/content/data_9/test/10757_165.png', '/content/data_9/test/10060_82-008.png', '/content/data_9/test/10254_82-254.png', '/content/data_9/test/12642_76-502.png', '/content/data_9/test/12810_64-355.png', '/content/data_9/test/12289_91-283.png', '/content/data_9/test/10296_78-099.png', '/content/data_9/test/11099_57-252.png', '/content/data_9/test/10080_79-436.png', '/content/data_9/test/11876_91-303.png', '/content/data_9/test/12640_75-948.png', '/content/data_9/test/10990_70-929.png', '/content/data_9/test/10010_83-552.png', '/content/data_9/test/12721_90-158.png', '/content/data_9/test/12733_90-117.png', '/content/data_9/test/11683_69-983.png', '/content/data_9/test/11688_69-06.png', '/content/data_9/test/10909_72-539.png', '/content/data_9/test/12819_66-173.png', '/content/data_9/test/11810_86-043.png', '/content/data_9/test/12173_89-821.png', '/content/data_9/test/10480_150-9.png', '/content/data_9/test/11687_69-259.png', '/content/data_9/test/10846_107-809.png', '/content/data_9/test/11542_95-235.png', '/content/data_9/test/12323_131-655.png', '/content/data_9/test/12763_84-609.png', '/content/data_9/test/11898_101-701.png', '/content/data_9/test/10877_96-493.png', '/content/data_9/test/11262_86-496.png', '/content/data_9/test/11482_118-887.png', '/content/data_9/test/10806_121-999.png', '/content/data_9/test/11138_66-834.png', '/content/data_9/test/11642_69-271.png', '/content/data_9/test/12277_89-684.png', '/content/data_9/test/10283_79-105.png', '/content/data_9/test/11418_97-665.png', '/content/data_9/test/12191_76-539.png', '/content/data_9/test/10895_90-307.png', '/content/data_9/test/12701_89-948.png', '/content/data_9/test/10759_165.png', '/content/data_9/test/11563_88-522.png', '/content/data_9/test/10329_76-652.png', '/content/data_9/test/10367_77-63.png', '/content/data_9/test/12154_96-264.png', '/content/data_9/test/10005_83-365.png', '/content/data_9/test/10818_117-982.png', '/content/data_9/test/12372_116-466.png', '/content/data_9/test/12324_131-865.png', '/content/data_9/test/11281_86-007.png', '/content/data_9/test/12613_72-644.png', '/content/data_9/test/10549_107-017.png', '/content/data_9/test/11973_123-333.png', '/content/data_9/test/12386_115-416.png', '/content/data_9/test/12373_116-056.png', '/content/data_9/test/11726_71-605.png', '/content/data_9/test/10348_76-771.png', '/content/data_9/test/10705_89-396.png', '/content/data_9/test/11308_85-546.png', '/content/data_9/test/11635_66-897.png', '/content/data_9/test/10305_77-652.png', '/content/data_9/test/11143_68-227.png', '/content/data_9/test/10369_77-767.png', '/content/data_9/test/10799_123-921.png', '/content/data_9/test/10672_81-162.png', '/content/data_9/test/12018_119-681.png', '/content/data_9/test/10824_115-837.png', '/content/data_9/test/12972_76-485.png', '/content/data_9/test/12200_73-423.png', '/content/data_9/test/12270_88-032.png', '/content/data_9/test/11982_120-887.png', '/content/data_9/test/11354_86-703.png', '/content/data_9/test/10271_80-896.png', '/content/data_9/test/10111_76-063.png', '/content/data_9/test/11671_72-571.png', '/content/data_9/test/12771_78-081.png', '/content/data_9/test/11328_85-662.png', '/content/data_9/test/10317_77-032.png', '/content/data_9/t ...
# ['/content/data_9/test/10000_83-126.png', '/content/data_9/test/10001_83-178.png', '/content/data_9/test/10002_83-225.png', '/content/data_9/test/10003_83-276.png', '/content/data_9/test/10004_83-332.png', '/content/data_9/test/10005_83-365.png', '/content/data_9/test/10006_83-401.png', '/content/data_9/test/10007_83-442.png', '/content/data_9/test/10008_83-475.png', '/content/data_9/test/10009_83-511.png', '/content/data_9/test/10010_83-552.png', '/content/data_9/test/10011_83-575.png', '/content/data_9/test/10012_83-594.png', '/content/data_9/test/10013_83-619.png', '/content/data_9/test/10014_83-645.png', '/content/data_9/test/10015_83-666.png', '/content/data_9/test/10016_83-692.png', '/content/data_9/test/10017_83-704.png', '/content/data_9/test/10018_83-708.png', '/content/data_9/test/10019_83-717.png', '/content/data_9/test/10020_83-731.png', '/content/data_9/test/10021_83-74.png', '/content/data_9/test/10022_83-752.png', '/content/data_9/test/10023_83-749.png', '/content/data_9/test/10024_83-739.png', '/content/data_9/test/10025_83-733.png', '/content/data_9/test/10026_83-733.png', '/content/data_9/test/10027_83-733.png', '/content/data_9/test/10028_83-731.png', '/content/data_9/test/10029_83-71.png', '/content/data_9/test/10030_83-685.png', '/content/data_9/test/10031_83-665.png', '/content/data_9/test/10032_83-651.png', '/content/data_9/test/10033_83-642.png', '/content/data_9/test/10034_83-627.png', '/content/data_9/test/10035_83-584.png', '/content/data_9/test/10036_83-543.png', '/content/data_9/test/10037_83-51.png', '/content/data_9/test/10038_83-482.png', '/content/data_9/test/10039_83-461.png', '/content/data_9/test/10040_83-43.png', '/content/data_9/test/10041_83-366.png', '/content/data_9/test/10042_83-311.png', '/content/data_9/test/10043_83-264.png', '/content/data_9/test/10044_83-223.png', '/content/data_9/test/10045_83-189.png', '/content/data_9/test/10046_83-129.png', '/content/data_9/test/10047_83-051.png', '/content/data_9/test/10048_82-981.png', '/content/data_9/test/10049_82-921.png', '/content/data_9/test/10050_82-868.png', '/content/data_9/test/10051_82-817.png', '/content/data_9/test/10052_82-728.png', '/content/data_9/test/10053_82-634.png', '/content/data_9/test/10054_82-551.png', '/content/data_9/test/10055_82-478.png', '/content/data_9/test/10056_82-413.png', '/content/data_9/test/10057_82-317.png', '/content/data_9/test/10058_82-215.png', '/content/data_9/test/10059_82-106.png', '/content/data_9/test/10060_82-008.png', '/content/data_9/test/10061_81-921.png', '/content/data_9/test/10062_81-818.png', '/content/data_9/test/10063_81-686.png', '/content/data_9/test/10064_81-565.png', '/content/data_9/test/10065_81-437.png', '/content/data_9/test/10066_81-321.png', '/content/data_9/test/10067_81-218.png', '/content/data_9/test/10068_81-063.png', '/content/data_9/test/10069_80-923.png', '/content/data_9/test/10070_80-794.png', '/content/data_9/test/10071_80-658.png', '/content/data_9/test/10072_80-534.png', '/content/data_9/test/10073_80-401.png', '/content/data_9/test/10074_80-247.png', '/content/data_9/test/10075_80-109.png', '/content/data_9/test/10076_79-982.png', '/content/data_9/test/10077_79-845.png', '/content/data_9/test/10078_79-722.png', '/content/data_9/test/10079_79-582.png', '/content/data_9/test/10080_79-436.png', '/content/data_9/test/10081_79-307.png', '/content/data_9/test/10082_79-186.png', '/content/data_9/test/10083_79-054.png', '/content/data_9/test/10084_78-938.png', '/content/data_9/test/10085_78-808.png', '/content/data_9/test/10086_78-673.png', '/content/data_9/test/10087_78-556.png', '/content/data_9/test/10088_78-441.png', '/content/data_9/test/10089_78-316.png', '/content/data_9/test/10090_78-208.png', '/content/data_9/test/10091_78-1.png', '/content/data_9/test/10092_77-977.png', '/content/data_9/test/10093_77-872.png', '/content/data_9/test/10094_77-758.png', '/content/data_9/test/10095_77-639.png', '/content/data_9/test/10096_77-538.png', '/content/data_9/test/10097_ ...
# [83.126, 83.178, 83.225, 83.276, 83.332, 83.365, 83.401, 83.442, 83.475, 83.511, 83.552, 83.575, 83.594, 83.619, 83.645, 83.666, 83.692, 83.704, 83.708, 83.717, 83.731, 83.74, 83.752, 83.749, 83.739, 83.733, 83.733, 83.733, 83.731, 83.71, 83.685, 83.665, 83.651, 83.642, 83.627, 83.584, 83.543, 83.51, 83.482, 83.461, 83.43, 83.366, 83.311, 83.264, 83.223, 83.189, 83.129, 83.051, 82.981, 82.921, 82.868, 82.817, 82.728, 82.634, 82.551, 82.478, 82.413, 82.317, 82.215, 82.106, 82.008, 81.921, 81.818, 81.686, 81.565, 81.437, 81.321, 81.218, 81.063, 80.923, 80.794, 80.658, 80.534, 80.401, 80.247, 80.109, 79.982, 79.845, 79.722, 79.582, 79.436, 79.307, 79.186, 79.054, 78.938, 78.808, 78.673, 78.556, 78.441, 78.316, 78.208, 78.1, 77.977, 77.872, 77.758, 77.639, 77.538, 77.453, 77.343, 77.246, 77.126, 77.006, 76.903, 76.817, 76.735, 76.637, 76.516, 76.397, 76.295, 76.21, 76.142, 76.063, 75.95, 75.834, 75.735, 75.655, 75.591, 75.538, 75.451, 75.34, 75.247, 75.172, 75.114, 75.067, 75.027, 74.936, 74.851, 74.784, 74.734, 74.697, 74.675, 74.63, 74.569, 74.511, 74.471, 74.445, 74.435, 74.423, 74.396, 74.37, 74.339, 74.326, 74.326, 74.344, 74.338, 74.341, 74.352, 74.348, 74.36, 74.388, 74.423, 74.436, 74.466, 74.511, 74.535, 74.573, 74.628, 74.673, 74.713, 74.768, 74.838, 74.896, 74.958, 75.035, 75.093, 75.156, 75.234, 75.324, 75.415, 75.495, 75.591, 75.663, 75.745, 75.841, 75.947, 76.067, 76.161, 76.269, 76.353, 76.449, 76.559, 76.678, 76.81, 76.921, 77.037, 77.13, 77.236, 77.353, 77.479, 77.617, 77.739, 77.858, 77.955, 78.065, 78.185, 78.314, 78.453, 78.574, 78.692, 78.789, 78.898, 79.016, 79.142, 79.278, 79.39, 79.502, 79.595, 79.698, 79.81, 79.93, 80.058, 80.151, 80.254, 80.339, 80.433, 80.537, 80.648, 80.746, 80.83, 80.921, 80.995, 81.08, 81.173, 81.272, 81.33, 81.401, 81.479, 81.541, 81.614, 81.695, 81.742, 81.79, 81.849, 81.911, 81.961, 82.022, 82.054, 82.078, 82.113, 82.161, 82.207, 82.247, 82.253, 82.255, 82.268, 82.294, 82.333, 82.362, 82.331, 82.311, 82.306, 82.312, 82.332, 82.335, 82.254, 82.192, 82.149, 82.123, 82.111, 82.115, 82.12, 82.093, 81.955, 81.844, 81.755, 81.688, 81.622, 81.425, 81.253, 81.117, 81.012, 80.896, 80.704, 80.528, 80.365, 80.241, 80.104, 79.918, 79.768, 79.651, 79.528, 79.395, 79.227, 79.105, 79.019, 78.962, 78.868, 78.718, 78.61, 78.542, 78.508, 78.491, 78.383, 78.257, 78.171, 78.12, 78.099, 78.088, 78.03, 77.994, 77.976, 77.91, 77.843, 77.799, 77.712, 77.652, 77.609, 77.525, 77.458, 77.415, 77.349, 77.291, 77.226, 77.144, 77.089, 77.06, 77.052, 77.032, 76.965, 76.892, 76.844, 76.821, 76.82, 76.807, 76.746, 76.693, 76.664, 76.658, 76.673, 76.652, 76.618, 76.589, 76.582, 76.593, 76.614, 76.59, 76.579, 76.58, 76.588, 76.613, 76.63, 76.618, 76.622, 76.639, 76.67, 76.713, 76.738, 76.749, 76.771, 76.803, 76.846, 76.896, 76.932, 76.956, 76.989, 77.03, 77.078, 77.13, 77.175, 77.208, 77.247, 77.291, 77.352, 77.415, 77.477, 77.524, 77.575, 77.63, 77.69, 77.767, 77.844, 77.906, 77.971, 78.037, 78.105, 78.186, 78.279, 78.359, 78.438, 78.518, 78.597, 78.678, 78.788, 78.894, 78.999, 79.102, 79.203, 79.302, 79.436, 79.568, 79.698, 79.824, 79.947, 80.065, 80.231, 80.39, 80.545, 80.696, 80.848, 81.013, 81.218, 81.413, 81.603, 81.787, 81.971, 82.223, 82.466, 82.702, 82.93, 83.148, 83.453, 83.751, 84.039, 84.316, 84.594, 84.965, 85.316, 85.653, 85.963, 86.361, 86.772, 87.156, 87.501, 87.916, 88.338, 88.717, 89.037, 89.4, 89.695, 89.885, 89.995, 90.052, 90.282, 90.8, 91.651, 92.983, 94.916, 97.629, 101.133, 105.57, 110.747, 116.18, 121.418, 126.125, 130.259, 133.786, 136.899, 139.633, 142.155, 144.46, 146.553, 148.534, 150.39, 152.112, 153.721, 155.266, 156.729, 158.098, 159.4, 160.64, 161.816, 162.922, 163.702, 164.415, 164.947, 165.0, 165.0, 164.759, 164.366, 163.83, 163.171, 162.303, 161.287, 160.171, 158.993, 157.68, 156.345, 155.035, 153.684, 152.286, 150.9, 149.482, 148.116, 146.817, 145.414, 144.038, 142.669, 141.385, 140.141, 138.896, 137.641, 136.445, 135.187, 134.084, 132.931, 131.887, 130.84, 129.679, 128.679, 127. ...

# %% [markdown]
# ## Part 4: Loading in the images
#
# The below code is outside the scope of this course but a brief explanation is provided nevertheless.
#
# ### Dataset Creation
# The dataset creation involves the creation of what is known as a dataset pipeline. All this is, is a sequence of transformations applied one after the other that manipulate the data in different ways.
# 1. from_tensor_slices. We load in the images and the steering angles into the dataset
# 2. repeat. Simply loop the dataset for infinity when we get to the end. This is done to make sure our network never runs out of data. For instance we train on batches of 32 if we had 52 images we would run out of data.
# 3. shuffle. Self explanatory makes sure we don't feed network ordered data as this can cause weird issues. Note we don't need to do this with our validation data so we might as well save the unnecessary operation by excluding shuffle.
# 4. batch. Tell the dataset that when we fetch a item from it is should return a number of items. This is more efficient as you almost certainly have enough RAM to handle more than 1 image.
# 5. Prefetch. Tell the dataset that when it's not doing anything it should automatically be loading data into RAM in the background. This results in huge performance increases as when we're training we don't have to sit around waiting for the dataset to load the images.

# %%
import matplotlib.pyplot as plt # import matplotlib for plotting
import tensorflow as tf
import cv2 as cv
from google.colab.patches import cv2_imshow
import numpy as np
import tqdm

train_data = []
test_data = []

tqdm.tqdm.write("Loading training data")
# load the images and steering angles into numpy arrays
for path in tqdm.tqdm(train_img):
    img = cv.imread(path) # read the image
    hsv = cv.cvtColor(img, cv.COLOR_BGR2HSV)
    # mask the image to get only the desired colors
    mask = cv.inRange(hsv, (36, 0, 0), (70, 255,255))
    array = np.array(mask, dtype=np.float32)
    train_data.append(array)

tqdm.tqdm.write("Loading test data")
# loading the testing data
for path in tqdm.tqdm(test_img):
    img = cv.imread(path) # read the image
    hsv = cv.cvtColor(img, cv.COLOR_BGR2HSV)
    # mask the image to get only the desired colors
    mask = cv.inRange(hsv, (36, 0, 0), (70, 255,255))
    array = np.array(mask, dtype=np.float32)
    test_data.append(array)

# create a dataset from the training data and make a data pipeline
train_ds = tf.data.Dataset.from_tensor_slices((train_data, train_steer)) # create a dataset from the image paths and steering angles
train_ds = train_ds.repeat()
train_ds = train_ds.shuffle(buffer_size=len(train_img)) # shuffle the dataset
train_ds = train_ds.batch(BATCH_SIZE) # batch the dataset
train_ds = train_ds.prefetch(tf.data.experimental.AUTOTUNE) # prefetch the dataset to improve performance

# create a dataset from the testing data and make a data pipeline
test_ds = tf.data.Dataset.from_tensor_slices((test_data, test_steer)) # create a dataset from the image paths and steering angles
test_ds = test_ds.repeat() # repeat the dataset
test_ds = test_ds.batch(BATCH_SIZE) # batch the dataset
test_ds = test_ds.prefetch(tf.data.experimental.AUTOTUNE) # prefetch the dataset to improve performance

# output the first 16 images and steering angles from the dataset
fig, axs = plt.subplots(4, 4, figsize=(8, 8))
# add title to the figure
fig.suptitle('Training Data')
fig.tight_layout()

imgs, steer = next(iter(train_ds)) # get the first batch of images and steering angles

for i in range(16):
    axs[i//4, i%4].axis('off')
    axs[i//4, i%4].imshow(imgs[i])
    axs[i//4, i%4].set_title(round(steer[i].numpy(), 2))
plt.tight_layout()
plt.show()
# Out:
# Loading training data
# 100%|██████████| 10000/10000 [00:03<00:00, 2883.62it/s]
# Loading test data
# 100%|██████████| 3000/3000 [00:01<00:00, 2821.91it/s]

# %% [markdown]
# ## Part 5: This is where you will create your model
# try modifying the layers to try to get the lowest mse score,
# This is going to require some trial and error so make sure you spend some time experimenting.

# %%
import numpy as np
np.random.seed(1337)  # for reproducibility
import keras as ks
from keras.models import Sequential
from keras.layers import Dense, InputLayer, Conv2D, Flatten, MaxPool2D, Dropout
from keras.optimizers import Adam
import matplotlib.pyplot as plt

# a sequential model is a model that is made up of layers
model = Sequential()
# the input layer is the first layer in the model. You shouldn't need to change this.
model.add(InputLayer(input_shape=(66, 100, 1), batch_size=BATCH_SIZE))

# try modifying the number of nodes in the hidden layer to see how it affects the model
# you can also try changing the activation function to see how it affects the model
# adding more layers to the model may also help you to acheive your score

# in this lab you also have access to the Conv2D layer and MaxPool2D layer. Try modifying these to see how they affect the model.
model.add(Conv2D(32, (3, 3), activation='relu'))  # conv layer 32 filters size 3x3
model.add(MaxPool2D(pool_size=(2, 2)))  # pooling layer size 3x3
model.add(Conv2D(64, (3, 3), activation='relu'))  # conv filters size 3x3
model.add(MaxPool2D(pool_size=(2, 2)))  # pooling layer size

model.add(Flatten())  # flatten layer
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='linear'))

optimizer = Adam(learning_rate=0.0001)  # try changing the learning rate to see how it affects the model
model.compile(optimizer=optimizer, loss='mse')  # we will keep track of the mean squared error

print(model.summary())  # print a summary of the model

# Train the model without EarlyStopping
epoch = 15
hist = model.fit(train_ds,
                 steps_per_epoch=len(train_img) // BATCH_SIZE,
                 validation_data=test_ds,
                 validation_steps=len(test_img) // BATCH_SIZE,
                 epochs=epoch)  # EarlyStopping removed

# let's plot the model's history
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
# plt.plot(np.log(hist.history['loss']))       # log scale
# plt.plot(np.log(hist.history['val_loss']))   # log scale
plt.title('model mean squared error loss')
plt.ylabel('mean squared error loss')
plt.xlabel('epoch')
plt.legend(['training set', 'validation set'], loc='upper right')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (32, 64, 98, 32)       │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (32, 32, 49, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (32, 30, 47, 64)       │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (32, 15, 23, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (32, 22080)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (32, 32)               │       706,592 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (32, 16)               │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (32, 1)                │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 725,953 (2.77 MB)
#  Trainable params: 725,953 (2.77 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/15
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 415.8984 - val_loss: 129.7361
# Epoch 2/15
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 187.1718 - val_loss: 75.8432
# Epoch 3/15
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 99.1388 - val_loss: 35.7830
# Epoch 4/15
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 55.4943 - val_loss: 27.3376
# Epoch 5/15
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 48.1726 - val_loss: 31.5450
# Epoch 6/15
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 42.3984 - val_loss: 19.2151
# Epoch 7/15
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 41.9018 - val_loss: 20.6597
# Epoch 8/15
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 45.2888 - val_loss: 21.0438
# Epoch 9/15
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 36.7752 - val_loss: 20.3315
# Epoch 10/15
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 40.4047 - val_loss: 20.9123
# Epoch 11/15
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 36.6506 - val_loss: 19.5763
# Epoch 12/15
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 37.3337 - val_loss: 19.4120
# Epoch 13/15
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 39.8743 - val_loss: 18.7795
# Epoch 14/15
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 42.3270 - val_loss: 18.6183
# Epoch 15/15
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 35.7661 - val_loss: 17.4273

# %% [markdown]
# Have a look at the graph generated below. With this you can get an idea of whether your model is training well. You should want to see both lines trend downwards.

# %% [markdown]
# ## Part 6: Test the model
# We'll now output 16 images with the predicted steering angles along with the actual steering angles

# %%
# output the first 16 images and steering angles from the test dataset then predict the steering angle for the images
fig, axs = plt.subplots(4, 4, figsize=(8, 8))
# add title to the figure
fig.suptitle('Training Data')
fig.tight_layout()

imgs, steer = next(iter(test_ds)) # get the first batch of images and steering angles

for i in range(16):
    axs[i//4, i%4].axis('off')
    axs[i//4, i%4].imshow(imgs[i])
    axs[i//4, i%4].set_title(round(steer[i].numpy(), 2))
    predicted = model(imgs[i].numpy().reshape(1, 66, 100, 1)) # predict the steering angle for the image
    axs[i//4, i%4].set_title("Predicted: " + str(np.round(predicted[0][0].numpy(), 2)) + "\n Actual: " + str(round(steer[i].numpy(), 2)))
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Part 7: export your model
# Once you are happy with your model you can export it by running the code below.
# This will save your model as model.h5 and model.onnx.
#
# The ".h5" model is used for the physical PiCar and the ".onnx" model is used for the PiCar Simulator. You can change this to be more descriptive. I also recommend saving multiple models with different training settings so you have a couple to experiment with.

# %%
# !pip install onnx
# !pip install tf2onnx
# Out:
# Collecting onnx
#   Downloading onnx-1.21.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.5 kB)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.12/dist-packages (from onnx) (2.0.2)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx) (5.29.6)
# Requirement already satisfied: typing_extensions>=4.7.1 in /usr/local/lib/python3.12/dist-packages (from onnx) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx) (0.5.4)
# Downloading onnx-1.21.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 106.3 MB/s eta 0:00:00
# Installing collected packages: onnx
# Successfully installed onnx-1.21.0
# Collecting tf2onnx
#   Downloading tf2onnx-1.17.0-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.12/dist-packages (from tf2onnx) (2.0.2)
# Requirement already satisfied: onnx>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from tf2onnx) (1.21.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from tf2onnx) (2.32.4)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.12/dist-packages (from tf2onnx) (25.12.19)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.12/dist-packages (from tf2onnx) (5.29.6)
# Requirement already satisfied: typing_extensions>=4.7.1 in /usr/local/lib/python3.12/dist-packages (from onnx>=1.14.0->tf2onnx) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx>=1.14.0->tf2onnx) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->tf2onnx) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->tf2onnx) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->tf2onnx) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->tf2onnx) (2026.2.25)
# Downloading tf2onnx-1.17.0-py3-none-any.whl (839 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 839.1/839.1 kB 22.0 MB/s eta 0:00:00
# Installing collected packages: tf2onnx
# Successfully installed tf2onnx-1.17.0

# %%
import onnx
import tf2onnx
import tensorflow as tf

model_name = "conv_model" # change the name to something more descriptive if you want
model.save(model_name + '.keras')
model.save(model_name + ".h5")
model.output_names = ['output']
input_signature = [tf.TensorSpec([None, 66, 100, 1], tf.float32, name='input')]

onnx_model, _ = tf2onnx.convert.from_keras(model, input_signature=input_signature, opset=13)

onnx.save(onnx_model, model_name + ".onnx")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
